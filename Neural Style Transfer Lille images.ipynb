# %% [markdown]
# # **Neural Style Transfer with Lille images using Pytorch**
# ---

# %%
# import resources
# %matplotlib inline

import os

from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

from instaloader import Instaloader, Profile
from fastai.vision import *
from fastai.vision import verify_images
from pathlib import Path
import itertools

import torch
import torch.optim as optim
from torchvision import *

# %%
current_path = Path('/content/drive/My Drive/')

# %% [markdown]
# ## **Download requirements**
# ---

# %%
# !pip install -r "/content/drive/My Drive/resources/requirements.txt"
# Out:
# Collecting git+https://github.com/bleshik/instaloader.git (from -r /content/drive/My Drive/resources/requirements.txt (line 1))
#   Cloning https://github.com/bleshik/instaloader.git to /tmp/pip-req-build-p9tkei04
#   Running command git clone -q https://github.com/bleshik/instaloader.git /tmp/pip-req-build-p9tkei04
# Requirement already satisfied (use --upgrade to upgrade): instaloader==4.2.6 from git+https://github.com/bleshik/instaloader.git in /usr/local/lib/python3.6/dist-packages (from -r /content/drive/My Drive/resources/requirements.txt (line 1))
# Requirement already satisfied: requests>=2.4 in /usr/local/lib/python3.6/dist-packages (from instaloader==4.2.6->-r /content/drive/My Drive/resources/requirements.txt (line 1)) (2.21.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.4->instaloader==4.2.6->-r /content/drive/My Drive/resources/requirements.txt (line 1)) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.4->instaloader==4.2.6->-r /content/drive/My Drive/resources/requirements.txt (line 1)) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.4->instaloader==4.2.6->-r /content/drive/My Drive/resources/requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.4->instaloader==4.2.6->-r /content/drive/My Drive/resources/requirements.txt (line 1)) (2019.11.28)
# Building wheels for collected packages: instaloader
#   Building wheel for instaloader (setup.py) ... done
#   Created wheel for instaloader: filename=instaloader-4.2.6-cp36-none-any.whl size=41606 sha256=e862f4e322642cc7639389929c77af94c0e811728bb3910751a44a83f118d0dc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2jwjgiyx/wheels/6b/99/f9/f37a7414fbe8f3b65e10fff1997066aa80618578a9e0ba3687
# Successfully built instaloader

# %% [markdown]
# ##**Download images**

# %% [markdown]
# ### **Download Lille images (content)**
# ---

# %%
# Get current directory
content_path = Path('drive/My Drive/data/content/')
folder = "dataset_lille_images"
txt_file_name = "lille_images_urls.txt"

# Create the directories to store the images
os.makedirs(path/folder, exist_ok=True)

# %% [markdown]
# Get URLs images of instagram posts using instaloader library and write them into a txt file

# %%
loader = Instaloader(download_videos=False,
                 download_video_thumbnails=False,
                 download_geotags=False,
                 download_comments=False,
                 save_metadata=False,
                 compress_json=False,)

profile_name = "lillemaville"
profile = Profile.from_username(loader.context, profile_name)

# %%
file = open(path/txt_file_name, 'w')

for post in itertools.islice(profile.get_posts(), 50):
    file.write("%s\n" % post.url)
    
file.close()

# %% [markdown]
# Download the retrieved images with Fastai

# %%
path_content_imgs = content_path/folder

print("Downloading Lille Images...")
download_images(urls=content_path/txt_file_name, dest=path_content_imgs)

# verify images have correct properties for training
print("Delete Corrupted Images...")
verify_images(path_content_imgs, delete=True, img_format=f'{folder} %d')
# Out:
# Downloading Lille Images...
# Delete Corrupted Images...

# %% [markdown]
# ### **Download style images**

# %%
# !wget https://oceanmhs.org/wp-content/uploads/2018/01/starrynight.jpg
# Out:
# --2020-02-06 14:01:39--  https://oceanmhs.org/wp-content/uploads/2018/01/starrynight.jpg
# Resolving oceanmhs.org (oceanmhs.org)... 104.155.134.146
# Connecting to oceanmhs.org (oceanmhs.org)|104.155.134.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 92567 (90K) [image/jpeg]
# Saving to: ‘starrynight.jpg’
#
# starrynight.jpg     100%[===================>]  90.40K   352KB/s    in 0.3s
#
# 2020-02-06 14:01:40 (352 KB/s) - ‘starrynight.jpg’ saved [92567/92567]

# %% [markdown]
# ## **Data exploration** - Looking at the data...

# %%
#TODO : Data visualisation of Lille images

# %% [markdown]
# ## **Data Loader**

# %%
# desired size of the output image
imsize = 512 if torch.cuda.is_available() else 128  # use small size if no gpu

# %% [markdown]
# VGG networks are trained on images with each channel normalized by mean=[0.485, 0.456, 0.406] and std=[0.229, 0.224, 0.225]. We will use them to normalize the image before sending it into the network.

# %%
transform = transforms.Compose([
    transforms.Resize(imsize),  # scale imported image
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
    ])  # transform it into a torch tensor

# %%
content_data = datasets.ImageFolder("/content/drive/My Drive/data/content", transform=transform)

# %%
dataloader = DataLoader(content_data, batch_size=4, shuffle=True, num_workers=2)
print(f"Number of Lille images: {len(dataloader.dataset)}")
# Out:
# Number of Lille images: 50

# %%
# dataset_subset = torch.utils.data.RandomSampler(content_data, replacement=True, num_samples=1)
# dataset_subset.dataset
# Out:
# 1

# %% [markdown]
# ## **Importing the model** (test VGG19)

# %%
class VGG19(nn.Module):
    def __init__(self):
        super(VGG19, self).__init__()
        # Load VGG Skeleton (only convolutional and pooling layers)
        self.features = models.vgg19(pretrained=True).features

        # Freeze all VGG parameters
        for param in self.features.parameters():
            param.requires_grad = False

    def forward(self, x):
        layers = {'0': 'conv1_1',
                  '5': 'conv2_1',
                  '10': 'conv3_1',
                  '19': 'conv4_1',
                  '21': 'conv4_2', ## content representation
                  '28': 'conv5_1'}

        features = {}
        for name, layer in self.features._modules.items():
            x = layer(x)
            if name in layers:
                features[layers[name]] = x

        return features

# %%
# style = load_image("/content/drive/My Drive/data/style/starrynight.jpg")
# model = VGG19()
# style_features = model(style)

# %%
# style_features
# Out:
# {'conv1_1': tensor([[[[0.0000, 0.0000, 0.0000,  ..., 0.6605, 0.8130, 0.5558],
#            [0.0000, 0.0000, 0.0000,  ..., 0.5165, 0.5896, 0.3959],
#            [0.0418, 0.0000, 0.0000,  ..., 0.7128, 0.9100, 0.5979],
#            ...,
#            [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#           [[1.6026, 0.0000, 0.1762,  ..., 1.5498, 1.4392, 4.4417],
#            [3.9469, 1.4979, 1.5243,  ..., 0.0000, 0.0000, 3.7629],
#            [2.1865, 1.9848, 0.4359,  ..., 0.0000, 0.0000, 3.9241],
#            ...,
#            [4.0430, 0.5507, 0.6079,  ..., 0.3050, 0.3050, 0.0000],
#            [4.0063, 0.5335, 0.6126,  ..., 0.3050, 0.3050, 0.0000],
#            [5.0541, 3.2208, 3.3730,  ..., 3.3390, 3.3390, 0.1079]],
#
#           [[0.0000, 0.0000, 0.0000,  ..., 0.9293, 1.2137, 0.6682],
#            [0.0000, 0.0000, 0.0000,  ..., 0.7231, 1.0291, 0.5766],
#            [0.0000, 0.0000, 0.0000,  ..., 0.2644, 0.3825, 0.0175],
#            ...,
#            [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#           ...,
#
#           [[1.6983, 2.4011, 1.6544,  ..., 0.0000, 0.0000, 0.0000],
#            [2.3137, 2.8346, 2.0258,  ..., 0.0000, 0.0000, 0.0000],
#            [1.8052, 1.9597, 1.6137,  ..., 0.0000, 0.0000, 0.0000],
#            ...,
#            [0.0000, 0.3401, 0.4186,  ..., 0.4734, 0.4734, 1.0721],
#            [0.0000, 0.3130, 0.3947,  ..., 0.4734, 0.4734, 1.0721],
#            [0.0000, 0.1983, 0.2583,  ..., 0.3115, 0.3115, 0.7140]],
#
#           [[0.8269, 2.8744, 2.4574,  ..., 0.0000, 0.0000, 0.0000],
#            [0.0000, 0.4786, 0.3683,  ..., 1.2425, 0.8966, 0.0000],
#            [0.0000, 0.0000, 0.0000,  ..., 1.3760, 1.1411, 0.0638],
#            ...,
#            [0.0000, 0.2318, 0.1974,  ..., 0.3500, 0.3500, 0.7610],
#            [0.0000, 0.2692, 0.2228,  ..., 0.3500, 0.3500, 0.7610],
#            [0.4421, 1.1056, 1.0808,  ..., 1.2243, 1.2243, 1.4160]],
#
#           [[0.0000, 0.0000, 0.0000,  ..., 3.8537, 4.2308, 4.0685],
#            [0.8448, 1.3418, 1.4196,  ..., 0.0000, 0.0000, 0.7960],
#            [2.2585, 1.4724, 1.1441,  ..., 0.0000, 0.0000, 0.0000],
#            ...,
#            [0.0000, 0.5136, 0.4747,  ..., 0.3298, 0.3298, 0.0000],
#            [0.0000, 0.3408, 0.3307,  ..., 0.3298, 0.3298, 0.0000],
#            [0.2658, 1.1449, 1.2818,  ..., 1.3496, 1.3496, 0.0000]]]]),
#  'conv2_1': tensor([[[[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.5063,  0.0000,  0.0000,  ...,  0.0000,  0.3392,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            ...,
#            [ 0.5102,  2.1705,  1.0652,  ...,  2.1358,  1.1865,  0.7263],
#            [ 0.0874,  0.3236,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#           [[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.5490,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.1428,  0.7072,  ...,  0.0000,  5.3946,  0.0000],
#            ...,
#            [ 0.0000,  0.0000,  0.2860,  ...,  0.0637,  1.6585,  0.0000],
#            [ 0.0000,  0.0000,  1.8242,  ...,  1.1071,  2.1024,  0.2869],
#            [ 0.0000,  0.0000,  1.9290,  ...,  1.4917,  1.7694,  0.7953]],
#
#           [[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  5.4124,  1.4781,  ...,  0.7614,  3.8462,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  1.3087,  1.8449],
#            ...,
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.7495,  2.1496,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.8580,  2.3623,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#           ...,
#
#           [[ 8.4126,  5.5954,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [17.4278, 11.2591,  0.0000,  ...,  5.1254,  0.0000,  0.0000],
#            [ 7.7240,  1.6594,  0.0000,  ..., 24.0259, 21.3774, 14.1588],
#            ...,
#            [ 2.8494,  1.4286,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.5642,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.2666],
#            [ 0.6005,  2.4349,  5.1231,  ...,  1.9194,  1.7583,  2.2887]],
#
#           [[ 4.6885,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            ...,
#            [ 4.4654,  1.6373,  0.0000,  ...,  0.0000,  1.5444,  1.2584],
#            [ 5.7594,  4.2169,  0.7742,  ...,  0.6178,  3.7541,  1.8002],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#           [[ 4.1195,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.5344,  0.0000,  1.2380,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            ...,
#            [ 0.0000,  0.2424,  0.0000,  ...,  0.0000,  0.5834,  0.0000],
#            [ 0.3628,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  1.0692,  0.0000,  ...,  0.0000,  0.0000,  0.0000]]]]),
#  'conv3_1': tensor([[[[ 5.9684,  0.8487,  0.0000,  ...,  0.0000,  0.0000,  2.4744],
#            [ 8.3408,  2.3186,  2.3690,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  7.2913,  0.0000,  0.0000],
#            ...,
#            [ 0.0000,  0.0565,  1.3369,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  1.4164,  ...,  0.3463,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  5.2655,  ...,  2.5449,  0.1815,  1.2194]],
#
#           [[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 1.3996,  0.0000,  0.0000,  ...,  0.0000,  0.8755, 11.7454],
#            [ 5.0462,  0.0000,  0.0000,  ...,  0.0000,  3.5265, 23.5663],
#            ...,
#            [ 0.5578,  0.0000,  0.0000,  ...,  8.3467,  6.9237,  3.2296],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.4687,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  2.3037,  0.0000,  0.0000]],
#
#           [[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [17.9172,  0.0000,  0.0000,  ..., 11.2375,  6.1670, 10.6345],
#            [11.8031,  0.0000,  0.0000,  ...,  0.0000,  5.7334, 14.6562],
#            ...,
#            [ 8.2011,  0.0000,  1.1081,  ...,  7.3445, 10.4795,  5.3327],
#            [ 5.7588,  0.0000,  0.0000,  ...,  0.7666,  0.0000,  0.0000],
#            [13.8886,  7.6844,  5.8099,  ...,  9.0644,  6.7877,  5.4425]],
#
#           ...,
#
#           [[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  2.5314],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  5.7728, 10.2017],
#            ...,
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  2.4286,  0.0000],
#            [ 0.0000,  0.0000,  2.4733,  ...,  0.0000,  0.0000,  2.2431],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#           [[14.1351,  0.0000,  0.0000,  ..., 15.8117, 23.1193,  7.6291],
#            [ 9.2811,  0.0000,  7.3487,  ..., 13.4341, 18.3526,  7.3170],
#            [ 8.8412,  0.0000,  0.0000,  ..., 16.2790,  9.4374,  2.3949],
#            ...,
#            [ 0.0000,  0.0000,  1.9943,  ...,  1.7321,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.3952,  0.0000,  0.0371,  ...,  0.0000,  0.0000,  0.0000]],
#
#           [[ 1.3068,  5.3522,  5.0592,  ..., 12.3622,  5.5757,  0.0000],
#            [ 1.1996,  9.8571,  2.8757,  ..., 12.4115,  5.4899,  0.0000],
#            [ 0.0000,  7.8117,  0.0000,  ...,  3.7358,  1.0242,  7.8236],
#            ...,
#            [ 2.3385,  0.6106,  0.0000,  ...,  0.0000,  5.6179,  5.0353],
#            [ 3.9080,  3.5341,  0.0000,  ...,  0.0000,  4.7135,  5.2405],
#            [ 9.6928, 12.1836,  5.3072,  ...,  5.5799,  8.9355,  7.2555]]]]),
#  'conv4_1': tensor([[[[ 0.0000,  0.0000,  2.6266,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            ...,
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000, 12.0159],
#            [ 6.2064,  2.1218,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#           [[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.6069],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            ...,
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.3086],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.4458],
#            [ 7.5448,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  6.1524]],
#
#           [[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            ...,
#            [ 1.1182,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#           ...,
#
#           [[ 0.0000,  3.2013,  0.0000,  ...,  0.0000,  6.6365, 18.3536],
#            [ 3.7282, 14.1281,  1.5201,  ...,  0.0000,  0.0000, 10.8741],
#            [ 1.5346,  8.2848,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            ...,
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 5.3317,  6.9657,  0.5781,  ...,  2.1974,  9.5241,  2.7764]],
#
#           [[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            ...,
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#           [[ 0.0000,  0.0000,  0.0000,  ...,  0.5164,  0.0000,  2.3948],
#            [12.6462,  5.3743,  7.2185,  ..., 10.4067,  9.9407,  6.5233],
#            [ 7.6931,  1.5165,  0.0000,  ...,  6.9854, 14.0244,  8.9948],
#            ...,
#            [ 3.6578,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 6.9768,  0.0000,  5.2704,  ...,  0.0000,  0.0000,  0.0000],
#            [ 4.7663,  0.0000,  3.1988,  ...,  0.0000,  0.0000,  0.0000]]]]),
#  'conv4_2': tensor([[[[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 7.1416,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 1.9736,  0.0000,  5.4720,  ...,  0.0000,  0.6974,  0.0000],
#            ...,
#            [ 0.0000,  0.2382,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.6475,  0.0000,  0.0000]],
#
#           [[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            ...,
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  8.1323,  6.3372,  4.4273]],
#
#           [[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            ...,
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#           ...,
#
#           [[ 5.7328,  0.0000,  0.0000,  ...,  0.9751,  4.5281, 13.6043],
#            [ 8.4242,  0.0000,  0.0000,  ...,  0.2353,  0.0000,  4.0122],
#            [10.7528,  0.0000,  0.0000,  ...,  9.9768,  3.7084,  0.0000],
#            ...,
#            [16.9121,  8.7641,  6.0936,  ...,  0.0000,  0.0000,  0.0000],
#            [13.8812,  2.9413,  3.1113,  ...,  0.0000,  0.0000,  0.0000],
#            [15.6965,  7.1154, 12.8064,  ...,  0.0000,  0.0000,  4.0922]],
#
#           [[ 0.0000,  0.0000,  4.0344,  ...,  0.0000,  4.3292,  6.9765],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 0.0000,  0.0000,  0.4355,  ...,  0.0000,  0.0000,  0.0000],
#            ...,
#            [ 2.7163,  0.0000,  0.4534,  ...,  0.0000,  0.0000,  0.0000],
#            [ 1.9374,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [ 2.3160,  0.3913,  0.0000,  ...,  0.0000,  0.0000,  0.0000]],
#
#           [[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#            [16.3332,  0.7526,  8.7089,  ...,  0.0000,  0.0000, 12.7519],
#            [11.6375,  0.0000, 10.4626,  ...,  0.0000,  0.0000,  9.5800],
#            ...,
#            [ 1.3430,  0.0000,  2.5017,  ...,  0.0000,  0.0000,  0.0000],
#            [ 2.2166,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.2851],
#            [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000]]]]),
#  'conv5_1': tensor([[[[1.5307, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [2.1269, 0.4268, 1.6974,  ..., 0.0000, 0.0000, 0.2738],
#            ...,
#            [0.0000, 1.0181, 1.5330,  ..., 0.0000, 0.0000, 0.0000],
#            [0.0000, 0.0000, 4.8906,  ..., 0.0000, 0.0000, 0.0000],
#            [4.0252, 2.9622, 4.9033,  ..., 0.0000, 0.0000, 0.0000]],
#
#           [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [0.0000, 0.0000, 0.0000,  ..., 0.8075, 3.0821, 4.5341],
#            [0.0000, 0.8064, 0.0000,  ..., 0.0000, 0.0000, 0.3576],
#            ...,
#            [1.9622, 2.0372, 0.1339,  ..., 5.9764, 6.6276, 4.3586],
#            [0.0000, 0.0000, 0.0000,  ..., 4.5287, 4.6707, 3.7066],
#            [0.8718, 0.0000, 0.3219,  ..., 4.6953, 3.2845, 2.9226]],
#
#           [[0.0000, 0.0000, 0.0000,  ..., 0.8811, 7.6382, 6.0513],
#            [2.5378, 0.0000, 0.0000,  ..., 6.2705, 8.3358, 2.6556],
#            [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            ...,
#            [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [1.7362, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [5.5991, 5.0042, 1.2185,  ..., 0.9861, 1.3858, 1.3956]],
#
#           ...,
#
#           [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            ...,
#            [0.0000, 0.0000, 0.0000,  ..., 1.1033, 1.7932, 1.0272],
#            [0.0363, 0.0000, 0.0000,  ..., 0.1855, 1.4757, 0.4874],
#            [2.0070, 2.3096, 0.0000,  ..., 1.6278, 1.3086, 0.5152]],
#
#           [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [0.8000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [1.1724, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            ...,
#            [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#           [[0.5445, 0.0000, 0.0000,  ..., 0.1595, 0.0000, 0.0000],
#            [0.0000, 0.0000, 0.0000,  ..., 1.6046, 0.0000, 0.0000],
#            [0.0000, 0.0000, 0.0000,  ..., 1.4213, 0.0000, 0.0000],
#            ...,
#            [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#            [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.1597, 0.0000]]]])}

# %% [markdown]
# Gram Matrix

# %% [markdown]
# Loss and Weights

# %% [markdown]
# Optimizer (?)

# %% [markdown]
# Updating the Target & Calculating Losses

# %% [markdown]
# Save the target image
